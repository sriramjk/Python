# %%
import pandas as pd

# %%
df = pd.read_csv("mobile_cleaned.csv")

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
df.tail()
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 104        9.4           2                      2.0           2  ...
# 105        7.7           5                      5.0           3  ...
# 106        7.3           2                      5.0           3  ...
# 107        6.9           2                      1.2           3  ...
# 108        7.4           6                      8.0           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
df.shape
# Out:
# (109, 40)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df) # list all the function
# Out:
# ['FM',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
len(df)
# Out:
# 109

# %%
df.loc[5]
# Out:
# sim_type                                0.0
# aperture                               14.0
# gpu_rank                               55.0
# weight                                179.0
# stand_by_time                         280.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              5.0
# front_camera_resolution                 5.0
# auto_focus                              3.0
# screen_size                             5.5
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       6.0
# os                                      0.0
# phone_height                          150.0
# screen_protection                       5.0
# sim_size                                3.0
# price                                5999.0
# talk_time                              22.0
# video_resolution                      720.0
# ...

# %%
df_short = df.loc[0:10]

# %%
df_short
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0          0        12        55   155.0            250                  1.3
# 1          0         1        55   132.0            300                  1.3
# 2          0         9        55   142.0            329                  1.5
# 3          0         8        55   152.0            385                  1.3
# 4          1         1        55   234.0            385                  1.3
# 5          0        14        55   179.0            280                  1.3
# 6          1         1        56   124.0            230                  1.3
# 7          0         8        41   154.0            182                  1.0
# 8          1         8        41   214.0            182                  1.0
# 9          0         1        55   155.0            435                  1.3
# 10         0         1        55   169.0            514                  1.3
#
# ...

# %%
df_short = df[0: 10]
df_short
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
# 5         0        14        55   179.0            280                  1.3
# 6         1         1        56   124.0            230                  1.3
# 7         0         8        41   154.0            182                  1.0
# 8         1         8        41   214.0            182                  1.0
# 9         0         1        55   155.0            435                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# ...

# %%
df_short = df[0: 11: 2]
df_short
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0          0        12        55   155.0            250                  1.3
# 2          0         9        55   142.0            329                  1.5
# 4          1         1        55   234.0            385                  1.3
# 6          1         1        56   124.0            230                  1.3
# 8          1         8        41   214.0            182                  1.0
# 10         0         1        55   169.0            514                  1.3
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0        10.5           5                     2.00           0  ...
# 2         8.5           5                     2.00           3  ...
# 4         7.9           5                     1.92           3  ...
# 6         8.8           5                     2.00           3  ...
# 8         8.2           5                     2.00           3  ...
# ...

# %%
# This above techniques are selecting the subset of rows

# %%
df_thin = df[['stand_by_time', 'battery_capacity', 'price', 'is_liked']]
df_thin.head()
# Out:
#    stand_by_time  battery_capacity  price  is_liked
# 0            250              2000   3870         1
# 1            300              2000   4059         1
# 2            329              2500   4777         0
# 3            385              3000   5799         1
# 4            385              3000   5990         0

# %%
df_thin.shape
# Out:
# (109, 4)

# %%
df_liked = df_thin[df_thin['is_liked'] == 1]
df_liked.head()
# Out:
#    stand_by_time  battery_capacity  price  is_liked
# 0            250              2000   3870         1
# 1            300              2000   4059         1
# 3            385              3000   5799         1
# 6            230              1700   5999         1
# 7            182              2000   6599         1

# %%
df_liked.shape
# Out:
# (92, 4)

# %%
df_thin['price'].mean(), df_thin.price.mean()
# Out:
# (np.float64(19373.211009174312), np.float64(19373.211009174312))

# %%
df_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin.describe()
# Out:
#        stand_by_time  battery_capacity         price    is_liked
# count      109.00000        109.000000    109.000000  109.000000
# mean       404.66055       2841.779817  19373.211009    0.844037
# std        176.44206        655.003963  14039.197220    0.364496
# min        160.00000       1560.000000   3870.000000    0.000000
# 25%        264.00000       2470.000000   8999.000000    1.000000
# 50%        360.00000       2900.000000  14614.000000    1.000000
# 75%        500.00000       3100.000000  24999.000000    1.000000
# max       1093.00000       5000.000000  64500.000000    1.000000

# %%
df_thin[df_thin['is_liked'] == 1]['price'].mean()
# Out:
# np.float64(19393.239130434784)

# %%
df_thin[df_thin['is_liked'] == 0]['price'].mean()
# Out:
# np.float64(19264.823529411766)

# %%
g = df_thin.groupby(['is_liked'])

# %%
df_thin.shape
# Out:
# (109, 4)

# %%
df_thin.head()
# Out:
#    stand_by_time  battery_capacity  price  is_liked
# 0            250              2000   3870         1
# 1            300              2000   4059         1
# 2            329              2500   4777         0
# 3            385              3000   5799         1
# 4            385              3000   5990         0

# %%
for key, value in g:
    print(key)
    print(value)
# Out:
# (0,)
#      stand_by_time  battery_capacity  price  is_liked
# 2              329              2500   4777         0
# 4              385              3000   5990         0
# 5              280              2900   5999         0
# 11             300              2600   6990         0
# 22             354              2400   7999         0
# 38             490              2100   9999         0
# 53             345              2950  14300         0
# 60             840              4100  15689         0
# 74             390              2800  21999         0
# 77             620              3100  22999         0
# 78             618              3600  24499         0
# 80             598              3000  24999         0
# 83             504              2600  25500         0
# 90             500              3760  34999         0
# 91             240              1624  34999         0
# 95             580              2840  37766         0
# ...

# %%
59475*345
# Out:
# 20518875

# %%
df_thin.groupby(['is_liked']).count()
# Out:
#           stand_by_time  battery_capacity  price
# is_liked
# 0                    17                17     17
# 1                    92                92     92

# %%
df_thin.groupby(['is_liked']).mean()
# Out:
#           stand_by_time  battery_capacity         price
# is_liked
# 0            457.235294       2874.941176  19264.823529
# 1            394.945652       2835.652174  19393.239130

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = sns.pairplot(df_thin, diag_kind='hist') # diagonal is hist

# %%
ax = sns.pairplot(df_thin, diag_kind='hist', hue='is_liked')
